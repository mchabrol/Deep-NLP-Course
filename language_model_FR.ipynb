# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections
from collections import Counter

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = Counter(text) 
chars = set(counter)
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)

## YOUR CODE HERE
# first 90% will be train, rest val
split_idx = int(0.9*len(data))
train_data, val_data = data[:split_idx], data[split_idx:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([85066])
# context is >n< target is >o<
# context is >no< target is >r<
# context is >nor< target is >e<
# context is >nore< target is >,<
# context is >nore,< target is >
# <
# context is >nore,
# < target is >P<
# context is >nore,
# P< target is >a<
# context is >nore,
# Pa< target is >i<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = 'cpu'
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(0, len(data)-block_size, (batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i : i + block_size] for i in starting_points])
    # y is the character after each starting position
    y = torch.stack([data[i + 1 : i + block_size + 1] for i in starting_points])  


    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn
import torch.nn.functional as F

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.embedding = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.embedding(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = F.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 5.23724889755249

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE

start_token = torch.tensor([encode('\n')], dtype=torch.long).to(device) 
#start_token = torch.zeros((1,1), dtype=torch.long).to(device) 
generated_sequence = m.generate(start_token, max_new_tokens=100)
generated_text = decode(generated_sequence[0].tolist())
generated_text

###
# Out:
# [74]
# "\nbtOtyùîsÊkéjm7Eixk[HWéâcêè]OcZNruîuH6kVgpîÎKxH.N'RNWçDdO\nUÔFomaa(ë ù;-EMyL2ùR9eJêçIà0NriÉe\nà0YFeèéQE"

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.2653, val loss 5.2687
# step 10: train loss 5.2663, val loss 5.3044
# step 20: train loss 5.2084, val loss 5.2394
# step 30: train loss 5.2132, val loss 5.2887
# step 40: train loss 5.2237, val loss 5.2276
# step 50: train loss 5.1886, val loss 5.2441
# step 60: train loss 5.2256, val loss 5.2976
# step 70: train loss 5.1780, val loss 5.2268
# step 80: train loss 5.1967, val loss 5.1357
# step 90: train loss 5.1554, val loss 5.2076
# step 100: train loss 5.2296, val loss 5.1732
# step 110: train loss 5.1109, val loss 5.1999
# step 120: train loss 5.2193, val loss 5.1595
# step 130: train loss 5.1162, val loss 5.1387
# step 140: train loss 5.2232, val loss 5.1369
# step 150: train loss 5.1508, val loss 5.1853
# step 160: train loss 5.0567, val loss 5.1105
# step 170: train loss 5.1152, val loss 5.1297
# step 180: train loss 5.0909, val loss 5.1435
# step 190: train loss 5.0162, val loss 5.1518
# step 200: train loss 5.0619, val loss 5.1306
# step 210: train loss 5.1848, val loss 5.0481
# step 220: train loss 5.0986, val loss 5.0942
# step 230: train loss 5.1100, val loss 5.1576
# step 240: train loss 5.0732, val loss 5.1224
# step 250: train loss 5.0754, val loss 5.0814
# step 260: train loss 5.0661, val loss 5.0414
# step 270: train loss 4.9735, val loss 5.0134
# step 280: train loss 4.9850, val loss 5.1163
# step 290: train loss 4.9909, val loss 5.0059
# step 300: train loss 5.0837, val loss 5.0200
# step 310: train loss 4.9443, val loss 4.9779
# step 320: train loss 4.9600, val loss 4.9704
# step 330: train loss 4.9782, val loss 4.9573
# step 340: train loss 4.9702, val loss 4.9820
# step 350: train loss 4.9822, val loss 4.9464
# step 360: train loss 4.9253, val loss 4.9650
# step 370: train loss 4.9481, val loss 4.9324
# step 380: train loss 4.9442, val loss 4.9150
# step 390: train loss 4.9329, val loss 4.9804
# step 400: train loss 4.9440, val loss 5.0087
# step 410: train loss 4.9112, val loss 4.9354
# step 420: train loss 4.9011, val loss 4.9517
# step 430: train loss 4.8800, val loss 4.8648
# step 440: train loss 4.8617, val loss 4.9145
# step 450: train loss 4.9139, val loss 4.9049
# step 460: train loss 4.9414, val loss 4.8665
# step 470: train loss 4.8563, val loss 4.8190
# step 480: train loss 4.8816, val loss 4.8567
# step 490: train loss 4.8577, val loss 4.8308
# step 500: train loss 4.9066, val loss 4.8976
# step 510: train loss 4.8577, val loss 4.8256
# step 520: train loss 4.8534, val loss 4.8319
# step 530: train loss 4.8227, val loss 4.8229
# step 540: train loss 4.8530, val loss 4.7805
# step 550: train loss 4.7920, val loss 4.7941
# step 560: train loss 4.8232, val loss 4.8111
# step 570: train loss 4.7975, val loss 4.8501
# step 580: train loss 4.7336, val loss 4.7937
# step 590: train loss 4.7951, val loss 4.7608
# step 600: train loss 4.7358, val loss 4.7609
# step 610: train loss 4.7357, val loss 4.7796
# step 620: train loss 4.7336, val loss 4.7610
# step 630: train loss 4.7171, val loss 4.7261
# step 640: train loss 4.7466, val loss 4.7685
# step 650: train loss 4.6735, val loss 4.7182
# step 660: train loss 4.6966, val loss 4.6964
# step 670: train loss 4.6901, val loss 4.7381
# step 680: train loss 4.6849, val loss 4.7089
# step 690: train loss 4.7111, val loss 4.6832
# step 700: train loss 4.7734, val loss 4.7196
# step 710: train loss 4.6152, val loss 4.7364
# step 720: train loss 4.6438, val loss 4.6709
# step 730: train loss 4.6439, val loss 4.6353
# step 740: train loss 4.6947, val loss 4.6873
# step 750: train loss 4.7438, val loss 4.6788
# step 760: train loss 4.6798, val loss 4.6525
# step 770: train loss 4.6663, val loss 4.6864
# step 780: train loss 4.6824, val loss 4.6388
# step 790: train loss 4.5623, val loss 4.6548
# step 800: train loss 4.5612, val loss 4.5423
# step 810: train loss 4.5663, val loss 4.5869
# step 820: train loss 4.5253, val loss 4.6204
# step 830: train loss 4.4896, val loss 4.6379
# step 840: train loss 4.6236, val loss 4.6366
# step 850: train loss 4.5471, val loss 4.5758
# step 860: train loss 4.5163, val loss 4.5844
# step 870: train loss 4.5544, val loss 4.6337
# step 880: train loss 4.6115, val loss 4.5685
# step 890: train loss 4.5114, val loss 4.6665
# step 900: train loss 4.5296, val loss 4.5195
# step 910: train loss 4.4573, val loss 4.5905
# step 920: train loss 4.4552, val loss 4.5100
# step 930: train loss 4.4545, val loss 4.5219
# step 940: train loss 4.4440, val loss 4.4934
# step 950: train loss 4.4601, val loss 4.4704
# step 960: train loss 4.4415, val loss 4.4657
# step 970: train loss 4.4501, val loss 4.4709
# step 980: train loss 4.4949, val loss 4.4005
# step 990: train loss 4.4052, val loss 4.4968
# step 1000: train loss 4.3893, val loss 4.4220
# step 1010: train loss 4.4224, val loss 4.4907
# step 1020: train loss 4.4590, val loss 4.4536
# step 1030: train loss 4.4397, val loss 4.4150
# step 1040: train loss 4.3739, val loss 4.4576
# step 1050: train loss 4.4371, val loss 4.4653
# step 1060: train loss 4.4063, val loss 4.4285
# step 1070: train loss 4.3242, val loss 4.4853
# step 1080: train loss 4.3286, val loss 4.4443
# step 1090: train loss 4.4497, val loss 4.4385
# step 1100: train loss 4.3912, val loss 4.3828
# step 1110: train loss 4.3435, val loss 4.3999
# step 1120: train loss 4.4054, val loss 4.3880
# step 1130: train loss 4.3632, val loss 4.4031
# step 1140: train loss 4.3874, val loss 4.4021
# step 1150: train loss 4.3618, val loss 4.3761
# step 1160: train loss 4.3461, val loss 4.3363
# step 1170: train loss 4.3363, val loss 4.3667
# step 1180: train loss 4.3404, val loss 4.3794
# step 1190: train loss 4.2528, val loss 4.3813
# step 1200: train loss 4.3049, val loss 4.2887
# step 1210: train loss 4.3784, val loss 4.3406
# step 1220: train loss 4.3252, val loss 4.3882
# step 1230: train loss 4.2776, val loss 4.3349
# step 1240: train loss 4.2645, val loss 4.3303
# step 1250: train loss 4.2997, val loss 4.3115
# step 1260: train loss 4.2590, val loss 4.3493
# step 1270: train loss 4.3439, val loss 4.2896
# step 1280: train loss 4.3114, val loss 4.3339
# step 1290: train loss 4.2504, val loss 4.3006
# step 1300: train loss 4.2355, val loss 4.2970
# step 1310: train loss 4.2915, val loss 4.3080
# step 1320: train loss 4.1893, val loss 4.2640
# step 1330: train loss 4.2226, val loss 4.2991
# step 1340: train loss 4.2692, val loss 4.2642
# step 1350: train loss 4.2424, val loss 4.2690
# step 1360: train loss 4.2066, val loss 4.2890
# step 1370: train loss 4.1724, val loss 4.2917
# step 1380: train loss 4.1766, val loss 4.1882
# step 1390: train loss 4.2104, val loss 4.2060
# step 1400: train loss 4.1685, val loss 4.2022
# step 1410: train loss 4.1775, val loss 4.2339
# step 1420: train loss 4.1575, val loss 4.2018
# step 1430: train loss 4.2506, val loss 4.1757
# step 1440: train loss 4.1234, val loss 4.2740
# step 1450: train loss 4.1786, val loss 4.2067
# step 1460: train loss 4.1391, val loss 4.1359
# step 1470: train loss 4.1272, val loss 4.2486
# step 1480: train loss 4.0789, val loss 4.2285
# step 1490: train loss 4.1142, val loss 4.1520
# step 1500: train loss 4.1717, val loss 4.2309
# step 1510: train loss 4.0839, val loss 4.1850
# step 1520: train loss 4.0937, val loss 4.2046
# step 1530: train loss 4.1202, val loss 4.1227
# step 1540: train loss 4.0655, val loss 4.1332
# step 1550: train loss 4.1342, val loss 4.1043
# step 1560: train loss 4.0552, val loss 4.1418
# step 1570: train loss 4.0093, val loss 4.0955
# step 1580: train loss 4.0941, val loss 4.1323
# step 1590: train loss 4.0682, val loss 4.1575
# step 1600: train loss 4.1549, val loss 4.1008
# step 1610: train loss 4.0298, val loss 4.1178
# step 1620: train loss 4.0042, val loss 4.1661
# step 1630: train loss 4.0606, val loss 4.0873
# step 1640: train loss 3.9983, val loss 4.0819
# step 1650: train loss 4.0245, val loss 4.1228
# step 1660: train loss 4.0855, val loss 3.9670
# step 1670: train loss 3.9921, val loss 4.0398
# step 1680: train loss 4.0815, val loss 4.1049
# step 1690: train loss 4.0210, val loss 4.0147
# step 1700: train loss 3.9827, val loss 4.0334
# step 1710: train loss 4.0316, val loss 4.0555
# step 1720: train loss 3.9373, val loss 4.0438
# step 1730: train loss 3.9360, val loss 3.9646
# step 1740: train loss 3.9672, val loss 3.9943
# step 1750: train loss 3.9874, val loss 4.0351
# step 1760: train loss 3.9744, val loss 4.0452
# step 1770: train loss 3.9091, val loss 4.0436
# step 1780: train loss 3.9812, val loss 4.0288
# step 1790: train loss 3.9585, val loss 4.0289
# step 1800: train loss 3.9359, val loss 3.9556
# step 1810: train loss 3.8657, val loss 4.0226
# step 1820: train loss 3.7935, val loss 4.0733
# step 1830: train loss 4.0041, val loss 3.9593
# step 1840: train loss 4.0000, val loss 3.9884
# step 1850: train loss 3.8157, val loss 4.0256
# step 1860: train loss 3.8882, val loss 4.0372
# step 1870: train loss 3.8944, val loss 3.9780
# step 1880: train loss 3.9296, val loss 3.9025
# step 1890: train loss 3.9582, val loss 4.0565
# step 1900: train loss 3.9721, val loss 4.0294
# step 1910: train loss 3.8934, val loss 3.9401
# step 1920: train loss 3.8743, val loss 3.8611
# step 1930: train loss 3.9172, val loss 3.9455
# step 1940: train loss 3.8786, val loss 4.0027
# step 1950: train loss 3.8614, val loss 3.8635
# step 1960: train loss 3.8702, val loss 3.8808
# step 1970: train loss 3.9005, val loss 3.9141
# step 1980: train loss 3.8272, val loss 3.9040
# step 1990: train loss 3.8620, val loss 3.9102
# step 2000: train loss 3.8664, val loss 3.9385
# step 2010: train loss 3.8754, val loss 3.8700
# step 2020: train loss 3.8746, val loss 3.9188
# step 2030: train loss 3.7825, val loss 3.8761
# step 2040: train loss 3.8159, val loss 3.8270
# step 2050: train loss 3.8166, val loss 3.8371
# step 2060: train loss 3.7472, val loss 3.9126
# step 2070: train loss 3.7650, val loss 3.8889
# step 2080: train loss 3.8267, val loss 3.8267
# step 2090: train loss 3.7709, val loss 3.8674
# step 2100: train loss 3.7301, val loss 3.7504
# step 2110: train loss 3.6984, val loss 3.8255
# step 2120: train loss 3.7832, val loss 3.9058
# step 2130: train loss 3.8256, val loss 3.8238
# step 2140: train loss 3.7137, val loss 3.8415
# step 2150: train loss 3.8448, val loss 3.8357
# step 2160: train loss 3.7790, val loss 3.7879
# step 2170: train loss 3.7439, val loss 3.8866
# step 2180: train loss 3.7897, val loss 3.7523
# step 2190: train loss 3.7462, val loss 3.8654
# step 2200: train loss 3.7259, val loss 3.7532
# step 2210: train loss 3.7145, val loss 3.8370
# step 2220: train loss 3.8247, val loss 3.7502
# step 2230: train loss 3.7515, val loss 3.8918
# step 2240: train loss 3.6804, val loss 3.7990
# step 2250: train loss 3.7007, val loss 3.8038
# step 2260: train loss 3.7622, val loss 3.7978
# step 2270: train loss 3.6844, val loss 3.8056
# step 2280: train loss 3.6975, val loss 3.7154
# step 2290: train loss 3.6707, val loss 3.7512
# step 2300: train loss 3.7161, val loss 3.8205
# step 2310: train loss 3.5980, val loss 3.6734
# step 2320: train loss 3.6312, val loss 3.6558
# step 2330: train loss 3.6800, val loss 3.6976
# step 2340: train loss 3.7215, val loss 3.7177
# step 2350: train loss 3.6897, val loss 3.7251
# step 2360: train loss 3.6391, val loss 3.7130
# step 2370: train loss 3.6508, val loss 3.7681
# step 2380: train loss 3.6237, val loss 3.6948
# step 2390: train loss 3.6864, val loss 3.7895
# step 2400: train loss 3.6733, val loss 3.6799
# step 2410: train loss 3.6114, val loss 3.7381
# step 2420: train loss 3.6032, val loss 3.7738
# step 2430: train loss 3.6311, val loss 3.6947
# step 2440: train loss 3.6100, val loss 3.6706
# step 2450: train loss 3.6225, val loss 3.7436
# step 2460: train loss 3.6012, val loss 3.6509
# step 2470: train loss 3.6382, val loss 3.6636
# step 2480: train loss 3.6104, val loss 3.6704
# step 2490: train loss 3.6074, val loss 3.6655
# step 2500: train loss 3.6566, val loss 3.6140
# step 2510: train loss 3.5720, val loss 3.6677
# step 2520: train loss 3.5858, val loss 3.7223
# step 2530: train loss 3.6105, val loss 3.7370
# step 2540: train loss 3.5238, val loss 3.6458
# step 2550: train loss 3.5705, val loss 3.5833
# step 2560: train loss 3.5356, val loss 3.6127
# step 2570: train loss 3.6374, val loss 3.6278
# step 2580: train loss 3.5711, val loss 3.5603
# step 2590: train loss 3.5817, val loss 3.5544
# step 2600: train loss 3.5913, val loss 3.6172
# step 2610: train loss 3.5207, val loss 3.6962
# step 2620: train loss 3.5720, val loss 3.6177
# step 2630: train loss 3.5452, val loss 3.5994
# step 2640: train loss 3.5249, val loss 3.6263
# step 2650: train loss 3.5591, val loss 3.6325
# step 2660: train loss 3.4268, val loss 3.5439
# step 2670: train loss 3.4695, val loss 3.5797
# step 2680: train loss 3.5321, val loss 3.5718
# step 2690: train loss 3.5667, val loss 3.5571
# step 2700: train loss 3.5599, val loss 3.5259
# step 2710: train loss 3.4569, val loss 3.5837
# step 2720: train loss 3.5773, val loss 3.5639
# step 2730: train loss 3.4924, val loss 3.4933
# step 2740: train loss 3.5120, val loss 3.5970
# step 2750: train loss 3.4451, val loss 3.5869
# step 2760: train loss 3.5280, val loss 3.5280
# step 2770: train loss 3.4622, val loss 3.5821
# step 2780: train loss 3.4858, val loss 3.4384
# step 2790: train loss 3.4193, val loss 3.5460
# step 2800: train loss 3.5042, val loss 3.5866
# step 2810: train loss 3.5034, val loss 3.5573
# step 2820: train loss 3.4729, val loss 3.5820
# step 2830: train loss 3.5056, val loss 3.5880
# step 2840: train loss 3.4503, val loss 3.5815
# step 2850: train loss 3.4695, val loss 3.5017
# step 2860: train loss 3.4775, val loss 3.5504
# step 2870: train loss 3.5266, val loss 3.4108
# step 2880: train loss 3.4389, val loss 3.5731
# step 2890: train loss 3.4493, val loss 3.5040
# step 2900: train loss 3.4773, val loss 3.4801
# step 2910: train loss 3.4443, val loss 3.4760
# step 2920: train loss 3.4535, val loss 3.5331
# step 2930: train loss 3.4194, val loss 3.5283
# step 2940: train loss 3.3900, val loss 3.6502
# step 2950: train loss 3.3715, val loss 3.4874
# step 2960: train loss 3.3993, val loss 3.4850
# step 2970: train loss 3.4295, val loss 3.5270
# step 2980: train loss 3.4025, val loss 3.4715
# step 2990: train loss 3.3830, val loss 3.4620
# step 3000: train loss 3.4525, val loss 3.4956
# step 3010: train loss 3.4555, val loss 3.3388
# step 3020: train loss 3.3818, val loss 3.3258
# step 3030: train loss 3.3483, val loss 3.5094
# step 3040: train loss 3.4018, val loss 3.4876
# step 3050: train loss 3.3365, val loss 3.3952
# step 3060: train loss 3.3029, val loss 3.3918
# step 3070: train loss 3.3612, val loss 3.4403
# step 3080: train loss 3.3752, val loss 3.4581
# step 3090: train loss 3.3213, val loss 3.3684
# step 3100: train loss 3.3616, val loss 3.5263
# step 3110: train loss 3.3853, val loss 3.5611
# step 3120: train loss 3.3990, val loss 3.4663
# step 3130: train loss 3.3300, val loss 3.4166
# step 3140: train loss 3.3668, val loss 3.4629
# step 3150: train loss 3.3312, val loss 3.3554
# step 3160: train loss 3.3919, val loss 3.4920
# step 3170: train loss 3.3006, val loss 3.4664
# step 3180: train loss 3.2516, val loss 3.2650
# step 3190: train loss 3.3346, val loss 3.3639
# step 3200: train loss 3.3872, val loss 3.4890
# step 3210: train loss 3.2991, val loss 3.4131
# step 3220: train loss 3.2968, val loss 3.2982
# step 3230: train loss 3.3096, val loss 3.4790
# step 3240: train loss 3.2680, val loss 3.4413
# step 3250: train loss 3.2527, val loss 3.3749
# step 3260: train loss 3.2585, val loss 3.3791
# step 3270: train loss 3.3106, val loss 3.3755
# step 3280: train loss 3.2591, val loss 3.4002
# step 3290: train loss 3.2860, val loss 3.4075
# step 3300: train loss 3.2819, val loss 3.2620
# step 3310: train loss 3.2286, val loss 3.3409
# step 3320: train loss 3.2311, val loss 3.3033
# step 3330: train loss 3.2422, val loss 3.3114
# step 3340: train loss 3.2433, val loss 3.4826
# step 3350: train loss 3.2681, val loss 3.2985
# step 3360: train loss 3.2201, val loss 3.3708
# step 3370: train loss 3.2602, val loss 3.3785
# step 3380: train loss 3.3085, val loss 3.3903
# step 3390: train loss 3.2833, val loss 3.3284
# step 3400: train loss 3.3322, val loss 3.2902
# step 3410: train loss 3.2002, val loss 3.2789
# step 3420: train loss 3.1732, val loss 3.2939
# step 3430: train loss 3.2937, val loss 3.3945
# step 3440: train loss 3.2739, val loss 3.3647
# step 3450: train loss 3.1615, val loss 3.2654
# step 3460: train loss 3.2692, val loss 3.2235
# step 3470: train loss 3.2778, val loss 3.4273
# step 3480: train loss 3.1102, val loss 3.3286
# step 3490: train loss 3.2212, val loss 3.2972
# step 3500: train loss 3.1869, val loss 3.2736
# step 3510: train loss 3.2543, val loss 3.3621
# step 3520: train loss 3.0954, val loss 3.4508
# step 3530: train loss 3.2107, val loss 3.2771
# step 3540: train loss 3.1648, val loss 3.2762
# step 3550: train loss 3.1970, val loss 3.3081
# step 3560: train loss 3.1895, val loss 3.3402
# step 3570: train loss 3.2013, val loss 3.3194
# step 3580: train loss 3.1550, val loss 3.3176
# step 3590: train loss 3.0759, val loss 3.2809
# step 3600: train loss 3.1858, val loss 3.3475
# step 3610: train loss 3.2010, val loss 3.2626
# step 3620: train loss 3.1603, val loss 3.2637
# step 3630: train loss 3.1669, val loss 3.3282
# step 3640: train loss 3.2118, val loss 3.2984
# step 3650: train loss 3.2793, val loss 3.3522
# step 3660: train loss 3.1550, val loss 3.2853
# step 3670: train loss 3.1542, val loss 3.2305
# step 3680: train loss 3.1403, val loss 3.1788
# step 3690: train loss 3.2460, val loss 3.3468
# step 3700: train loss 3.1806, val loss 3.2464
# step 3710: train loss 3.1814, val loss 3.3009
# step 3720: train loss 3.1508, val loss 3.2551
# step 3730: train loss 3.1176, val loss 3.2038
# step 3740: train loss 3.1126, val loss 3.2200
# step 3750: train loss 3.1488, val loss 3.1721
# step 3760: train loss 3.1250, val loss 3.2137
# step 3770: train loss 3.1408, val loss 3.2656
# step 3780: train loss 3.1775, val loss 3.2887
# step 3790: train loss 3.1328, val loss 3.1726
# step 3800: train loss 3.0612, val loss 3.1936
# step 3810: train loss 3.1297, val loss 3.1981
# step 3820: train loss 3.0685, val loss 3.3255
# step 3830: train loss 3.1652, val loss 3.2244
# step 3840: train loss 3.1407, val loss 3.1949
# step 3850: train loss 3.1537, val loss 3.2413
# step 3860: train loss 3.1215, val loss 3.3016
# step 3870: train loss 3.1802, val loss 3.2383
# step 3880: train loss 3.1428, val loss 3.2029
# step 3890: train loss 3.1759, val loss 3.3159
# step 3900: train loss 3.0598, val loss 3.0551
# step 3910: train loss 3.1489, val loss 3.2020
# step 3920: train loss 3.1524, val loss 3.3222
# step 3930: train loss 3.1450, val loss 3.2733
# step 3940: train loss 3.1263, val loss 3.0913
# step 3950: train loss 3.1738, val loss 3.1747
# step 3960: train loss 3.0809, val loss 3.1519
# step 3970: train loss 2.9985, val loss 3.2197
# step 3980: train loss 3.0942, val loss 3.1583
# step 3990: train loss 3.0753, val loss 3.1420
# step 4000: train loss 3.0715, val loss 3.1197
# step 4010: train loss 3.0586, val loss 3.1733
# step 4020: train loss 3.0091, val loss 3.2186
# step 4030: train loss 3.0767, val loss 3.2063
# step 4040: train loss 3.0192, val loss 3.1447
# step 4050: train loss 3.1122, val loss 3.2524
# step 4060: train loss 3.0098, val loss 3.1657
# step 4070: train loss 3.1297, val loss 3.1356
# step 4080: train loss 3.0492, val loss 3.0874
# step 4090: train loss 3.0175, val loss 3.0042
# step 4100: train loss 3.0108, val loss 3.1741
# step 4110: train loss 3.0190, val loss 3.1414
# step 4120: train loss 3.0545, val loss 3.1762
# step 4130: train loss 3.1011, val loss 3.1050
# step 4140: train loss 3.0274, val loss 3.1831
# step 4150: train loss 2.9231, val loss 3.0824
# step 4160: train loss 2.9748, val loss 3.1460
# step 4170: train loss 3.0072, val loss 3.0817
# step 4180: train loss 3.0046, val loss 3.2207
# step 4190: train loss 2.9842, val loss 3.1594
# step 4200: train loss 3.0405, val loss 3.1041
# step 4210: train loss 3.0304, val loss 3.1245
# step 4220: train loss 3.0048, val loss 3.1855
# step 4230: train loss 3.0096, val loss 3.1287
# step 4240: train loss 3.0356, val loss 3.1645
# step 4250: train loss 2.9978, val loss 3.1177
# step 4260: train loss 3.0443, val loss 2.9886
# step 4270: train loss 3.0196, val loss 3.1685
# step 4280: train loss 3.0738, val loss 3.1431
# step 4290: train loss 2.9737, val loss 3.1232
# step 4300: train loss 2.9777, val loss 3.1003
# step 4310: train loss 2.9948, val loss 3.0717
# step 4320: train loss 3.0081, val loss 3.1553
# step 4330: train loss 3.0515, val loss 3.2538
# step 4340: train loss 3.0985, val loss 3.0854
# step 4350: train loss 2.9923, val loss 3.1332
# step 4360: train loss 3.0106, val loss 3.0927
# step 4370: train loss 3.0018, val loss 3.1188
# step 4380: train loss 2.9667, val loss 3.0793
# step 4390: train loss 3.0064, val loss 3.0632
# step 4400: train loss 3.0596, val loss 3.0461
# step 4410: train loss 2.9315, val loss 3.0259
# step 4420: train loss 3.0097, val loss 3.0370
# step 4430: train loss 2.9686, val loss 3.1629
# step 4440: train loss 2.9176, val loss 3.0140
# step 4450: train loss 2.8896, val loss 3.0843
# step 4460: train loss 2.9689, val loss 3.1084
# step 4470: train loss 2.8971, val loss 3.1268
# step 4480: train loss 2.9865, val loss 2.9855
# step 4490: train loss 2.9270, val loss 3.0995
# step 4500: train loss 2.8705, val loss 3.0960
# step 4510: train loss 2.9556, val loss 3.0472
# step 4520: train loss 2.9746, val loss 3.0662
# step 4530: train loss 2.9941, val loss 3.0688
# step 4540: train loss 2.9409, val loss 3.0166
# step 4550: train loss 2.9133, val loss 3.0164
# step 4560: train loss 2.9226, val loss 2.9856
# step 4570: train loss 2.9635, val loss 3.0882
# step 4580: train loss 2.9163, val loss 3.0420
# step 4590: train loss 2.9658, val loss 3.1210
# step 4600: train loss 2.9955, val loss 3.0646
# step 4610: train loss 2.9248, val loss 3.0451
# step 4620: train loss 2.9737, val loss 3.0655
# step 4630: train loss 2.9173, val loss 3.0550
# step 4640: train loss 2.8533, val loss 3.0337
# step 4650: train loss 2.9374, val loss 3.0241
# step 4660: train loss 2.9804, val loss 3.0433
# step 4670: train loss 2.8903, val loss 3.0001
# step 4680: train loss 2.9713, val loss 3.0766
# step 4690: train loss 2.9959, val loss 3.0348
# step 4700: train loss 2.9524, val loss 3.0263
# step 4710: train loss 2.9269, val loss 2.9909
# step 4720: train loss 2.8814, val loss 3.0569
# step 4730: train loss 3.0003, val loss 2.9672
# step 4740: train loss 2.8824, val loss 3.0065
# step 4750: train loss 2.8638, val loss 2.9759
# step 4760: train loss 2.9062, val loss 2.9624
# step 4770: train loss 2.9426, val loss 3.0629
# step 4780: train loss 2.9073, val loss 3.0386
# step 4790: train loss 2.8702, val loss 3.0341
# step 4800: train loss 2.9169, val loss 3.0386
# step 4810: train loss 2.8909, val loss 2.9989
# step 4820: train loss 2.9249, val loss 3.0813
# step 4830: train loss 2.8819, val loss 2.9080
# step 4840: train loss 2.9267, val loss 2.9833
# step 4850: train loss 2.9931, val loss 3.1210
# step 4860: train loss 2.8825, val loss 3.0858
# step 4870: train loss 2.8310, val loss 2.9722
# step 4880: train loss 2.8607, val loss 3.0854
# step 4890: train loss 2.9172, val loss 3.0000
# step 4900: train loss 2.9463, val loss 3.0175
# step 4910: train loss 2.8836, val loss 2.9395
# step 4920: train loss 2.8184, val loss 2.8934
# step 4930: train loss 2.9442, val loss 2.8705
# step 4940: train loss 2.9550, val loss 3.0120
# step 4950: train loss 2.9137, val loss 2.9566
# step 4960: train loss 2.9143, val loss 2.8881
# step 4970: train loss 2.9074, val loss 3.0084
# step 4980: train loss 2.9080, val loss 2.9800
# step 4990: train loss 2.9505, val loss 3.0837
# step 5000: train loss 2.8358, val loss 3.1662
# step 5010: train loss 2.9467, val loss 3.0658
# step 5020: train loss 2.9065, val loss 2.9938
# step 5030: train loss 2.9282, val loss 2.9911
# step 5040: train loss 2.8734, val loss 2.9820
# step 5050: train loss 2.9401, val loss 2.9930
# step 5060: train loss 2.8886, val loss 3.0202
# step 5070: train loss 2.8002, val loss 2.9676
# step 5080: train loss 2.8523, val loss 2.9026
# step 5090: train loss 2.8401, val loss 2.9000
# step 5100: train loss 2.8461, val loss 3.0236
# step 5110: train loss 2.8786, val loss 2.9016
# step 5120: train loss 2.8342, val loss 3.0279
# step 5130: train loss 2.9020, val loss 2.9497
# step 5140: train loss 2.8164, val loss 2.8964
# step 5150: train loss 2.8904, val loss 2.9493
# step 5160: train loss 2.7959, val loss 3.1063
# step 5170: train loss 2.9285, val loss 2.9426
# step 5180: train loss 2.8631, val loss 2.9910
# step 5190: train loss 2.8385, val loss 2.9519
# step 5200: train loss 2.8123, val loss 2.9583
# step 5210: train loss 2.7448, val loss 3.1141
# step 5220: train loss 2.8429, val loss 2.9525
# step 5230: train loss 2.8178, val loss 3.0425
# step 5240: train loss 2.9211, val loss 3.0185
# step 5250: train loss 2.8309, val loss 2.8349
# step 5260: train loss 2.8293, val loss 2.8796
# step 5270: train loss 2.7808, val loss 2.9359
# step 5280: train loss 2.9115, val loss 2.9316
# step 5290: train loss 2.8470, val loss 2.8444
# step 5300: train loss 2.8304, val loss 2.9843
# step 5310: train loss 2.9021, val loss 2.8485
# step 5320: train loss 2.8183, val loss 2.9042
# step 5330: train loss 2.7791, val loss 2.9020
# step 5340: train loss 2.7899, val loss 2.8527
# step 5350: train loss 2.8466, val loss 2.9608
# step 5360: train loss 2.7736, val loss 2.8885
# step 5370: train loss 2.8083, val loss 2.8650
# step 5380: train loss 2.8289, val loss 2.9308
# step 5390: train loss 2.8150, val loss 2.8569
# step 5400: train loss 2.8654, val loss 2.8302
# step 5410: train loss 2.8081, val loss 2.9624
# step 5420: train loss 2.8064, val loss 2.9871
# step 5430: train loss 2.8514, val loss 2.9332
# step 5440: train loss 2.7820, val loss 2.8585
# step 5450: train loss 2.7884, val loss 2.9184
# step 5460: train loss 2.7956, val loss 2.9940
# step 5470: train loss 2.8175, val loss 2.8216
# step 5480: train loss 2.8264, val loss 2.7761
# step 5490: train loss 2.7970, val loss 2.8102
# step 5500: train loss 2.9420, val loss 3.0223
# step 5510: train loss 2.7709, val loss 2.8515
# step 5520: train loss 2.8609, val loss 2.9844
# step 5530: train loss 2.7450, val loss 2.8813
# step 5540: train loss 2.8392, val loss 2.9126
# step 5550: train loss 2.8257, val loss 2.8906
# step 5560: train loss 2.8241, val loss 2.8643
# step 5570: train loss 2.7138, val loss 2.8889
# step 5580: train loss 2.8191, val loss 2.8803
# step 5590: train loss 2.7439, val loss 2.9018
# step 5600: train loss 2.9310, val loss 2.9042
# step 5610: train loss 2.7735, val loss 2.8780
# step 5620: train loss 2.8009, val loss 2.8984
# step 5630: train loss 2.7631, val loss 2.9538
# step 5640: train loss 2.7633, val loss 2.8494
# step 5650: train loss 2.7688, val loss 2.9017
# step 5660: train loss 2.7975, val loss 2.9465
# step 5670: train loss 2.7426, val loss 2.8254
# step 5680: train loss 2.7501, val loss 2.9477
# step 5690: train loss 2.7297, val loss 3.0203
# step 5700: train loss 2.7852, val loss 2.8153
# step 5710: train loss 2.7327, val loss 2.9801
# step 5720: train loss 2.7421, val loss 2.9048
# step 5730: train loss 2.8189, val loss 2.8753
# step 5740: train loss 2.7136, val loss 2.8455
# step 5750: train loss 2.8143, val loss 2.8446
# step 5760: train loss 2.6720, val loss 2.8730
# step 5770: train loss 2.7375, val loss 2.8818
# step 5780: train loss 2.7554, val loss 2.7795
# step 5790: train loss 2.7507, val loss 2.9735
# step 5800: train loss 2.7521, val loss 2.9170
# step 5810: train loss 2.6773, val loss 2.7906
# step 5820: train loss 2.7276, val loss 2.8931
# step 5830: train loss 2.7027, val loss 2.9471
# step 5840: train loss 2.7432, val loss 2.9375
# step 5850: train loss 2.7473, val loss 2.8544
# step 5860: train loss 2.7455, val loss 2.8490
# step 5870: train loss 2.7383, val loss 2.8729
# step 5880: train loss 2.7641, val loss 2.8288
# step 5890: train loss 2.8043, val loss 2.8459
# step 5900: train loss 2.7853, val loss 2.9077
# step 5910: train loss 2.7246, val loss 2.8475
# step 5920: train loss 2.7514, val loss 2.7686
# step 5930: train loss 2.7164, val loss 2.7783
# step 5940: train loss 2.7532, val loss 2.8392
# step 5950: train loss 2.7549, val loss 2.8933
# step 5960: train loss 2.7126, val loss 3.0016
# step 5970: train loss 2.7926, val loss 2.7731
# step 5980: train loss 2.7239, val loss 2.8694
# step 5990: train loss 2.6916, val loss 2.7548
# step 6000: train loss 2.6437, val loss 2.9298
# step 6010: train loss 2.7749, val loss 2.6975
# step 6020: train loss 2.7130, val loss 2.9103
# step 6030: train loss 2.7572, val loss 2.9525
# step 6040: train loss 2.7231, val loss 2.7651
# step 6050: train loss 2.6636, val loss 2.7728
# step 6060: train loss 2.7646, val loss 2.7028
# step 6070: train loss 2.7861, val loss 2.7367
# step 6080: train loss 2.8064, val loss 2.8571
# step 6090: train loss 2.7029, val loss 2.8303
# step 6100: train loss 2.7641, val loss 2.7084
# step 6110: train loss 2.6723, val loss 2.7776
# step 6120: train loss 2.6567, val loss 2.8002
# step 6130: train loss 2.7012, val loss 2.6746
# step 6140: train loss 2.7534, val loss 2.8454
# step 6150: train loss 2.7579, val loss 2.9036
# step 6160: train loss 2.6956, val loss 2.8186
# step 6170: train loss 2.7752, val loss 2.7084
# step 6180: train loss 2.6774, val loss 2.7873
# step 6190: train loss 2.6999, val loss 2.7565
# step 6200: train loss 2.7729, val loss 2.7801
# step 6210: train loss 2.7497, val loss 2.7924
# step 6220: train loss 2.7144, val loss 2.7255
# step 6230: train loss 2.7396, val loss 2.8182
# step 6240: train loss 2.7039, val loss 2.8073
# step 6250: train loss 2.7853, val loss 2.7625
# step 6260: train loss 2.6516, val loss 2.8687
# step 6270: train loss 2.7086, val loss 2.7829
# step 6280: train loss 2.7687, val loss 2.7359
# step 6290: train loss 2.6766, val loss 2.7563
# step 6300: train loss 2.7571, val loss 2.8222
# step 6310: train loss 2.6457, val loss 2.8101
# step 6320: train loss 2.7029, val loss 2.8019
# step 6330: train loss 2.6394, val loss 2.8014
# step 6340: train loss 2.7649, val loss 2.7909
# step 6350: train loss 2.6792, val loss 2.8221
# step 6360: train loss 2.7171, val loss 2.7814
# step 6370: train loss 2.7252, val loss 2.7886
# step 6380: train loss 2.6765, val loss 2.6856
# step 6390: train loss 2.7052, val loss 2.8098
# step 6400: train loss 2.6914, val loss 2.7847
# step 6410: train loss 2.6644, val loss 2.8064
# step 6420: train loss 2.6897, val loss 2.7888
# step 6430: train loss 2.6589, val loss 2.7167
# step 6440: train loss 2.7248, val loss 2.8329
# step 6450: train loss 2.7574, val loss 2.7503
# step 6460: train loss 2.6523, val loss 2.8252
# step 6470: train loss 2.6517, val loss 2.8835
# step 6480: train loss 2.6389, val loss 2.7631
# step 6490: train loss 2.6898, val loss 2.7536
# step 6500: train loss 2.6561, val loss 2.8264
# step 6510: train loss 2.6139, val loss 2.6793
# step 6520: train loss 2.6592, val loss 2.7609
# step 6530: train loss 2.6657, val loss 2.7377
# step 6540: train loss 2.7890, val loss 2.8005
# step 6550: train loss 2.6057, val loss 2.7703
# step 6560: train loss 2.6372, val loss 2.8256
# step 6570: train loss 2.6145, val loss 2.7180
# step 6580: train loss 2.7243, val loss 2.7248
# step 6590: train loss 2.6837, val loss 2.7630
# step 6600: train loss 2.6887, val loss 2.8829
# step 6610: train loss 2.6153, val loss 2.8186
# step 6620: train loss 2.6743, val loss 2.7905
# step 6630: train loss 2.7440, val loss 2.6889
# step 6640: train loss 2.6068, val loss 2.7259
# step 6650: train loss 2.6701, val loss 2.8556
# step 6660: train loss 2.6901, val loss 2.6809
# step 6670: train loss 2.6726, val loss 2.8812
# step 6680: train loss 2.6687, val loss 2.7651
# step 6690: train loss 2.7330, val loss 2.8133
# step 6700: train loss 2.7057, val loss 2.8645
# step 6710: train loss 2.7007, val loss 2.7157
# step 6720: train loss 2.6026, val loss 2.7999
# step 6730: train loss 2.6786, val loss 2.9075
# step 6740: train loss 2.6388, val loss 2.7405
# step 6750: train loss 2.6670, val loss 2.7892
# step 6760: train loss 2.7052, val loss 2.7047
# step 6770: train loss 2.6769, val loss 2.7717
# step 6780: train loss 2.7138, val loss 2.7288
# step 6790: train loss 2.7124, val loss 2.6437
# step 6800: train loss 2.7012, val loss 2.8636
# step 6810: train loss 2.7123, val loss 2.7918
# step 6820: train loss 2.6896, val loss 2.8250
# step 6830: train loss 2.5923, val loss 2.7228
# step 6840: train loss 2.6512, val loss 2.7718
# step 6850: train loss 2.6256, val loss 2.7293
# step 6860: train loss 2.6431, val loss 2.7329
# step 6870: train loss 2.6593, val loss 2.8121
# step 6880: train loss 2.7220, val loss 2.7559
# step 6890: train loss 2.6523, val loss 2.8159
# step 6900: train loss 2.7309, val loss 2.7148
# step 6910: train loss 2.6351, val loss 2.6634
# step 6920: train loss 2.6763, val loss 2.7366
# step 6930: train loss 2.6067, val loss 2.7712
# step 6940: train loss 2.7184, val loss 2.7613
# step 6950: train loss 2.6225, val loss 2.6952
# step 6960: train loss 2.6431, val loss 2.7190
# step 6970: train loss 2.6216, val loss 2.7655
# step 6980: train loss 2.7331, val loss 2.7560
# step 6990: train loss 2.6350, val loss 2.5988
# step 7000: train loss 2.5774, val loss 2.8257
# step 7010: train loss 2.6258, val loss 2.6740
# step 7020: train loss 2.6345, val loss 2.6454
# step 7030: train loss 2.6157, val loss 2.8531
# step 7040: train loss 2.6273, val loss 2.7524
# step 7050: train loss 2.6191, val loss 2.7118
# step 7060: train loss 2.6084, val loss 2.6944
# step 7070: train loss 2.6366, val loss 2.7804
# step 7080: train loss 2.6658, val loss 2.6953
# step 7090: train loss 2.6554, val loss 2.7525
# step 7100: train loss 2.5899, val loss 2.6653
# step 7110: train loss 2.7110, val loss 2.9092
# step 7120: train loss 2.6197, val loss 2.7192
# step 7130: train loss 2.6996, val loss 2.6185
# step 7140: train loss 2.5941, val loss 2.6612
# step 7150: train loss 2.5766, val loss 2.7862
# step 7160: train loss 2.6000, val loss 2.8042
# step 7170: train loss 2.6581, val loss 2.9037
# step 7180: train loss 2.6285, val loss 2.6933
# step 7190: train loss 2.6282, val loss 2.6352
# step 7200: train loss 2.6186, val loss 2.8062
# step 7210: train loss 2.6202, val loss 2.6725
# step 7220: train loss 2.6279, val loss 2.7255
# step 7230: train loss 2.6400, val loss 2.7204
# step 7240: train loss 2.5467, val loss 2.6717
# step 7250: train loss 2.6920, val loss 2.6814
# step 7260: train loss 2.6006, val loss 2.7319
# step 7270: train loss 2.5891, val loss 2.7478
# step 7280: train loss 2.6844, val loss 2.6900
# step 7290: train loss 2.6779, val loss 2.7118
# step 7300: train loss 2.6965, val loss 2.7074
# step 7310: train loss 2.5335, val loss 2.7665
# step 7320: train loss 2.5994, val loss 2.7361
# step 7330: train loss 2.5849, val loss 2.6042
# step 7340: train loss 2.5828, val loss 2.7404
# step 7350: train loss 2.5858, val loss 2.6347
# step 7360: train loss 2.5965, val loss 2.8108
# step 7370: train loss 2.6529, val loss 2.6506
# step 7380: train loss 2.5539, val loss 2.7259
# step 7390: train loss 2.6362, val loss 2.7169
# step 7400: train loss 2.5996, val loss 2.6856
# step 7410: train loss 2.5564, val loss 2.7366
# step 7420: train loss 2.6418, val loss 2.7590
# step 7430: train loss 2.5873, val loss 2.5962
# step 7440: train loss 2.5635, val loss 2.6533
# step 7450: train loss 2.6368, val loss 2.6471
# step 7460: train loss 2.5846, val loss 2.7544
# step 7470: train loss 2.6139, val loss 2.6915
# step 7480: train loss 2.6713, val loss 2.7736
# step 7490: train loss 2.6184, val loss 2.7261
# step 7500: train loss 2.5723, val loss 2.6146
# step 7510: train loss 2.6482, val loss 2.7752
# step 7520: train loss 2.6390, val loss 2.8381
# step 7530: train loss 2.6187, val loss 2.7133
# step 7540: train loss 2.6299, val loss 2.7521
# step 7550: train loss 2.6589, val loss 2.5410
# step 7560: train loss 2.6125, val loss 2.7007
# step 7570: train loss 2.6026, val loss 2.6309
# step 7580: train loss 2.5633, val loss 2.6507
# step 7590: train loss 2.5333, val loss 2.6361
# step 7600: train loss 2.6198, val loss 2.7093
# step 7610: train loss 2.6177, val loss 2.7197
# step 7620: train loss 2.5847, val loss 2.6028
# step 7630: train loss 2.6213, val loss 2.6659
# step 7640: train loss 2.6053, val loss 2.6626
# step 7650: train loss 2.5915, val loss 2.6765
# step 7660: train loss 2.6528, val loss 2.6469
# step 7670: train loss 2.4942, val loss 2.5859
# step 7680: train loss 2.6163, val loss 2.6597
# step 7690: train loss 2.6314, val loss 2.7070
# step 7700: train loss 2.5962, val loss 2.6115
# step 7710: train loss 2.6575, val loss 2.5805
# step 7720: train loss 2.5388, val loss 2.6783
# step 7730: train loss 2.5998, val loss 2.6120
# step 7740: train loss 2.5718, val loss 2.6483
# step 7750: train loss 2.5566, val loss 2.5847
# step 7760: train loss 2.6324, val loss 2.6255
# step 7770: train loss 2.5646, val loss 2.6156
# step 7780: train loss 2.5682, val loss 2.6960
# step 7790: train loss 2.5910, val loss 2.6489
# step 7800: train loss 2.6213, val loss 2.7593
# step 7810: train loss 2.5107, val loss 2.7524
# step 7820: train loss 2.5710, val loss 2.6858
# step 7830: train loss 2.6384, val loss 2.7090
# step 7840: train loss 2.6302, val loss 2.6937
# step 7850: train loss 2.6086, val loss 2.7908
# step 7860: train loss 2.5381, val loss 2.7022
# step 7870: train loss 2.6734, val loss 2.6933
# step 7880: train loss 2.5718, val loss 2.8011
# step 7890: train loss 2.5359, val loss 2.7121
# step 7900: train loss 2.5798, val loss 2.6645
# step 7910: train loss 2.5780, val loss 2.6940
# step 7920: train loss 2.5401, val loss 2.6344
# step 7930: train loss 2.6040, val loss 2.7002
# step 7940: train loss 2.5641, val loss 2.7079
# step 7950: train loss 2.5481, val loss 2.5385
# step 7960: train loss 2.6176, val loss 2.6947
# step 7970: train loss 2.5572, val loss 2.6734
# step 7980: train loss 2.5994, val loss 2.6656
# step 7990: train loss 2.5515, val loss 2.6641
# step 8000: train loss 2.5170, val loss 2.7253
# step 8010: train loss 2.6170, val loss 2.6060
# step 8020: train loss 2.6062, val loss 2.5808
# step 8030: train loss 2.6228, val loss 2.7759
# step 8040: train loss 2.5771, val loss 2.6251
# step 8050: train loss 2.5270, val loss 2.6403
# step 8060: train loss 2.6060, val loss 2.6318
# step 8070: train loss 2.6191, val loss 2.6044
# step 8080: train loss 2.6363, val loss 2.8054
# step 8090: train loss 2.5583, val loss 2.6599
# step 8100: train loss 2.6193, val loss 2.7236
# step 8110: train loss 2.4703, val loss 2.5560
# step 8120: train loss 2.5628, val loss 2.6131
# step 8130: train loss 2.5248, val loss 2.8321
# step 8140: train loss 2.5584, val loss 2.6452
# step 8150: train loss 2.5194, val loss 2.5809
# step 8160: train loss 2.5783, val loss 2.6641
# step 8170: train loss 2.5464, val loss 2.6720
# step 8180: train loss 2.5718, val loss 2.6183
# step 8190: train loss 2.5695, val loss 2.5709
# step 8200: train loss 2.5525, val loss 2.6439
# step 8210: train loss 2.5064, val loss 2.6665
# step 8220: train loss 2.5763, val loss 2.5725
# step 8230: train loss 2.5052, val loss 2.6352
# step 8240: train loss 2.5608, val loss 2.5995
# step 8250: train loss 2.5363, val loss 2.6224
# step 8260: train loss 2.5738, val loss 2.7560
# step 8270: train loss 2.6811, val loss 2.6228
# step 8280: train loss 2.5315, val loss 2.6563
# step 8290: train loss 2.6440, val loss 2.6546
# step 8300: train loss 2.5092, val loss 2.5895
# step 8310: train loss 2.5584, val loss 2.6756
# step 8320: train loss 2.5598, val loss 2.5040
# step 8330: train loss 2.5079, val loss 2.5541
# step 8340: train loss 2.5548, val loss 2.7159
# step 8350: train loss 2.6451, val loss 2.5598
# step 8360: train loss 2.5693, val loss 2.6278
# step 8370: train loss 2.5203, val loss 2.6614
# step 8380: train loss 2.5818, val loss 2.6734
# step 8390: train loss 2.6290, val loss 2.6278
# step 8400: train loss 2.5723, val loss 2.7022
# step 8410: train loss 2.6036, val loss 2.6865
# step 8420: train loss 2.5640, val loss 2.7233
# step 8430: train loss 2.5909, val loss 2.6326
# step 8440: train loss 2.5799, val loss 2.7658
# step 8450: train loss 2.5715, val loss 2.6094
# step 8460: train loss 2.6165, val loss 2.6141
# step 8470: train loss 2.5412, val loss 2.6186
# step 8480: train loss 2.5116, val loss 2.5439
# step 8490: train loss 2.5498, val loss 2.6185
# step 8500: train loss 2.5251, val loss 2.7702
# step 8510: train loss 2.5687, val loss 2.6226
# step 8520: train loss 2.5013, val loss 2.6470
# step 8530: train loss 2.5942, val loss 2.6855
# step 8540: train loss 2.5755, val loss 2.7159
# step 8550: train loss 2.5735, val loss 2.5678
# step 8560: train loss 2.5092, val loss 2.6192
# step 8570: train loss 2.5438, val loss 2.6817
# step 8580: train loss 2.4993, val loss 2.5254
# step 8590: train loss 2.4591, val loss 2.5148
# step 8600: train loss 2.6177, val loss 2.5792
# step 8610: train loss 2.6164, val loss 2.6799
# step 8620: train loss 2.4972, val loss 2.6113
# step 8630: train loss 2.5777, val loss 2.6173
# step 8640: train loss 2.5448, val loss 2.5706
# step 8650: train loss 2.5487, val loss 2.5962
# step 8660: train loss 2.5133, val loss 2.5408
# step 8670: train loss 2.5243, val loss 2.5499
# step 8680: train loss 2.5218, val loss 2.7150
# step 8690: train loss 2.5698, val loss 2.5549
# step 8700: train loss 2.5270, val loss 2.6715
# step 8710: train loss 2.5475, val loss 2.6658
# step 8720: train loss 2.5524, val loss 2.6148
# step 8730: train loss 2.5519, val loss 2.6612
# step 8740: train loss 2.5217, val loss 2.6764
# step 8750: train loss 2.5701, val loss 2.6259
# step 8760: train loss 2.5794, val loss 2.5942
# step 8770: train loss 2.5133, val loss 2.5272
# step 8780: train loss 2.5449, val loss 2.7183
# step 8790: train loss 2.5863, val loss 2.7039
# step 8800: train loss 2.5787, val loss 2.6340
# step 8810: train loss 2.5200, val loss 2.5977
# step 8820: train loss 2.5251, val loss 2.5342
# step 8830: train loss 2.5150, val loss 2.7132
# step 8840: train loss 2.5000, val loss 2.5529
# step 8850: train loss 2.5548, val loss 2.6625
# step 8860: train loss 2.4526, val loss 2.5910
# step 8870: train loss 2.5342, val loss 2.5647
# step 8880: train loss 2.5263, val loss 2.5773
# step 8890: train loss 2.5231, val loss 2.6030
# step 8900: train loss 2.6010, val loss 2.6766
# step 8910: train loss 2.5413, val loss 2.6279
# step 8920: train loss 2.5634, val loss 2.5762
# step 8930: train loss 2.5559, val loss 2.6183
# step 8940: train loss 2.5405, val loss 2.6555
# step 8950: train loss 2.4634, val loss 2.6099
# step 8960: train loss 2.5085, val loss 2.5538
# step 8970: train loss 2.5573, val loss 2.5430
# step 8980: train loss 2.4957, val loss 2.6469
# step 8990: train loss 2.4943, val loss 2.6024
# step 9000: train loss 2.5749, val loss 2.5275
# step 9010: train loss 2.5515, val loss 2.7185
# step 9020: train loss 2.5340, val loss 2.6327
# step 9030: train loss 2.6052, val loss 2.6203
# step 9040: train loss 2.4847, val loss 2.6569
# step 9050: train loss 2.5043, val loss 2.5595
# step 9060: train loss 2.5241, val loss 2.5581
# step 9070: train loss 2.5360, val loss 2.7161
# step 9080: train loss 2.5606, val loss 2.6896
# step 9090: train loss 2.4953, val loss 2.5829
# step 9100: train loss 2.5200, val loss 2.5106
# step 9110: train loss 2.4892, val loss 2.5345
# step 9120: train loss 2.5594, val loss 2.5116
# step 9130: train loss 2.5088, val loss 2.5306
# step 9140: train loss 2.4489, val loss 2.5461
# step 9150: train loss 2.4832, val loss 2.5590
# step 9160: train loss 2.5733, val loss 2.5642
# step 9170: train loss 2.4973, val loss 2.4937
# step 9180: train loss 2.5752, val loss 2.5938
# step 9190: train loss 2.4693, val loss 2.5298
# step 9200: train loss 2.5189, val loss 2.5871
# step 9210: train loss 2.4887, val loss 2.6136
# step 9220: train loss 2.5887, val loss 2.5518
# step 9230: train loss 2.4246, val loss 2.5995
# step 9240: train loss 2.6075, val loss 2.5967
# step 9250: train loss 2.4843, val loss 2.5722
# step 9260: train loss 2.3900, val loss 2.5741
# step 9270: train loss 2.5756, val loss 2.5891
# step 9280: train loss 2.5257, val loss 2.6274
# step 9290: train loss 2.4962, val loss 2.5340
# step 9300: train loss 2.5587, val loss 2.6400
# step 9310: train loss 2.5165, val loss 2.5477
# step 9320: train loss 2.5252, val loss 2.6525
# step 9330: train loss 2.5202, val loss 2.6332
# step 9340: train loss 2.4530, val loss 2.5499
# step 9350: train loss 2.5040, val loss 2.5057
# step 9360: train loss 2.4699, val loss 2.6113
# step 9370: train loss 2.5054, val loss 2.5418
# step 9380: train loss 2.5157, val loss 2.5913
# step 9390: train loss 2.4651, val loss 2.6670
# step 9400: train loss 2.5131, val loss 2.6128
# step 9410: train loss 2.4649, val loss 2.6216
# step 9420: train loss 2.6009, val loss 2.5870
# step 9430: train loss 2.5804, val loss 2.5822
# step 9440: train loss 2.4675, val loss 2.6085
# step 9450: train loss 2.4652, val loss 2.6332
# step 9460: train loss 2.4903, val loss 2.5396
# step 9470: train loss 2.5156, val loss 2.6327
# step 9480: train loss 2.5218, val loss 2.6464
# step 9490: train loss 2.5578, val loss 2.5006
# step 9500: train loss 2.5142, val loss 2.5581
# step 9510: train loss 2.5501, val loss 2.6350
# step 9520: train loss 2.5311, val loss 2.5337
# step 9530: train loss 2.5287, val loss 2.5762
# step 9540: train loss 2.4811, val loss 2.6295
# step 9550: train loss 2.5832, val loss 2.6908
# step 9560: train loss 2.4842, val loss 2.6038
# step 9570: train loss 2.4803, val loss 2.5655
# step 9580: train loss 2.5306, val loss 2.5558
# step 9590: train loss 2.6298, val loss 2.5301
# step 9600: train loss 2.5086, val loss 2.5384
# step 9610: train loss 2.5295, val loss 2.6390
# step 9620: train loss 2.5523, val loss 2.5330
# step 9630: train loss 2.4686, val loss 2.5595
# step 9640: train loss 2.5278, val loss 2.5611
# step 9650: train loss 2.4991, val loss 2.6095
# step 9660: train loss 2.4732, val loss 2.5735
# step 9670: train loss 2.4464, val loss 2.6553
# step 9680: train loss 2.5586, val loss 2.6837
# step 9690: train loss 2.4157, val loss 2.6061
# step 9700: train loss 2.5424, val loss 2.5429
# step 9710: train loss 2.5040, val loss 2.5237
# step 9720: train loss 2.4688, val loss 2.5914
# step 9730: train loss 2.5115, val loss 2.5387
# step 9740: train loss 2.5429, val loss 2.6047
# step 9750: train loss 2.5447, val loss 2.5624
# step 9760: train loss 2.5059, val loss 2.6773
# step 9770: train loss 2.5129, val loss 2.4627
# step 9780: train loss 2.4169, val loss 2.5865
# step 9790: train loss 2.5377, val loss 2.6219
# step 9800: train loss 2.5135, val loss 2.6049
# step 9810: train loss 2.5655, val loss 2.5877
# step 9820: train loss 2.4590, val loss 2.5923
# step 9830: train loss 2.5318, val loss 2.5951
# step 9840: train loss 2.4666, val loss 2.4807
# step 9850: train loss 2.5229, val loss 2.4854
# step 9860: train loss 2.5400, val loss 2.6363
# step 9870: train loss 2.5321, val loss 2.6106
# step 9880: train loss 2.5767, val loss 2.6980
# step 9890: train loss 2.5460, val loss 2.6469
# step 9900: train loss 2.5972, val loss 2.4707
# step 9910: train loss 2.5149, val loss 2.5149
# step 9920: train loss 2.4758, val loss 2.6464
# step 9930: train loss 2.5185, val loss 2.5545
# step 9940: train loss 2.4867, val loss 2.5233
# step 9950: train loss 2.5124, val loss 2.6051
# step 9960: train loss 2.4636, val loss 2.5845
# step 9970: train loss 2.5699, val loss 2.5564
# step 9980: train loss 2.5272, val loss 2.5999
# step 9990: train loss 2.5180, val loss 2.6504

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# 7K!·uÆbÈHyV[Y56COcF,Y4zq1l)3ç»WzYNWMÆyE)_Q98U(çrbGxÂâm1NF(3bi6x_èzqàH )Bqw5vG2,êÊîFÈ)ov-î0jbÎrK,'RhÀç

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32 #T = Longueur de la séquence en tokens, C = embedding_size
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value =  nn.Linear(C, head_size)
# apply each layer to the input
k =  key(x) # (B, T, head_size)
q =  query(x) # (B, T, head_size)
v =  value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = q @  k.transpose(-2, -1) / head_size**0.5 # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[-0.6223, -0.8403,  0.8770, -0.1678,  0.6228, -0.5254,  0.3307,  0.5164,
#          -1.0467,  0.8915,  1.3585,  0.4345,  0.9845, -0.6521, -1.2440,  0.0842],
#         [-0.3074, -0.2785,  0.0576,  0.5540, -0.1868, -0.5902,  0.3331, -0.2634,
#          -0.0269, -0.0736,  0.0545,  0.0131, -0.3841, -0.1544, -0.1355,  0.6915],
#         [-0.2803, -0.2173,  0.0051,  0.4822, -0.0643, -0.4094,  0.5109, -0.2708,
#          -0.0923, -0.2303,  0.3738,  0.0389, -0.0028, -0.2761, -0.5243,  0.4964],
#         [-0.3797,  0.1062,  0.1096,  0.1810, -0.0766, -0.3564,  0.3248, -0.1292,
#           0.2338,  0.1002, -0.0162, -0.0527, -0.0445, -0.3618,  0.0964,  0.2665],
#         [-0.1641,  0.0931,  0.3656,  0.2048,  0.0992, -0.3080,  0.4659, -0.0654,
#          -0.1339,  0.0847,  0.2642,  0.0913,  0.0404, -0.3561, -0.2805,  0.1098],
#         [-0.2633, -0.0283,  0.3941,  0.2196, -0.1932, -0.3635,  0.1835, -0.1610,
#          -0.0838,  0.2262,  0.3614,  0.1258,  0.0800, -0.5217, -0.2344,  0.1406],
#         [-0.1502,  0.0676,  0.2279,  0.3674, -0.2426, -0.2651,  0.0979, -0.3504,
#           0.0189,  0.0573,  0.0476,  0.0219, -0.1076, -0.3933, -0.2406,  0.2403],
#         [-0.0791,  0.0149,  0.2046,  0.1618, -0.2745, -0.1666,  0.0689, -0.3524,
#          -0.0786,  0.0900,  0.0964, -0.0958, -0.1844, -0.2508, -0.0426,  0.3143]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %%
#train loss 2.34
#val loss 2.47
#le texte n'est pas specialement meilleur a premiere vue

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
n_embd = 32

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        # YOUR CODE
        # add you key, query and value definitions
        self.key = nn.Linear(n_embd, head_size)
        # define the Query layer
        self.query = nn.Linear(n_embd, head_size)
        # define the Value layer
        self.value =  nn.Linear(n_embd, head_size)
        ###
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))



    def forward(self, x):
        B,T,C = x.shape
        ## YOUR CODE HERE
        k =  self.key(x) # (B, T, head_size)
        q =  self.query(x) # (B, T, head_size)
        v =  self.value(x) # (B, T, head_size)
        # compute the normalize product between Q and K 
        weights = q @  k.transpose(-2, -1) / C**0.5 # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)
        # apply the mask (lower triangular matrix)
        tril = torch.tril(torch.ones(T,T))
        weights = weights.masked_fill(tril== 0, float('-inf'))
        # apply the softmax
        weights = nn.functional.softmax(weights, dim=-1)
        ###
        out  = weights @ self.value(x) # (B, T, head_size)

        ###
        out = weights @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
